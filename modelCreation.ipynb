# %%
# Import Cell
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestRegressor

from random import seed

# %%
#Files cleaning Cell: Transform the file into csv compatible
# Learning has only article sentiment and with Alchemy (bad model)
with open('/home/lucas/Desktop/learning.txt') as f:
    with open('/home/lucas/Desktop/cleaned.clean','w') as out:
        for line in f.readlines():
            out.write(','.join(line.split()) + '\n')
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-3-cab2ae212253> in <module>()
#       1 with open('/home/lucas/Desktop/learning.txt') as f:
# ----> 2     with open('/home/lucas/Desktop/cleaned.clean','w') as out:
#       3         for line in f.readlines():
#       4             out.write(','.join(line.split()) + '\n')
#
# IOError: [Errno 13] Permission denied: '/home/lucas/Desktop/cleaned.clean'

# %%
#Extract data from csv file
raw = pd.read_csv('/home/lucas/Desktop/cleaned.clean')
X = raw.ix[:,1].values
Y = raw.ix[:,0].values
features = np.array([X]).T

print raw
print features
print Y
# Out:
#       6  -473929
# 0     1  -458541
# 1    13  -400565
# 2    12  -388635
# 3     7  -374202
# 4     2  -355458
# 5    17  -354334
# 6    14  -309209
# 7    15  -266035
# 8    16  -238668
# 9    10  -236202
# 10    8  -213432
# 11   11  -172454
# 12    3  -156019
# 13   19  -126338
# 14    4     5109
# 15   18    43863
# 16    0   150469
# 17    9   166442
# 18   11  -452720
# 19   12  -401780
# 20    2  -382839
# 21    0  -372571
# 22    8  -340324
# 23   19  -334417
# 24   13  -265081
# 25    5  -253689
# 26    7  -206831
# 27    6  -205863
# 28   16  -199915
# 29   18  -183466
# ..   ..      ...
# 174  10  -236441
# 175  14  -234839
# 176  19  -219962
# 177   7  -183962
# 178  15   -80884
# 179  13   -66535
# 180   6   -61919
# 181  12   -55928
# 182   9    -6301
# 183  17   115415
# 184   8   161041
# 185   9  -547470
# 186   2  -496695
# 187   8  -427785
# 188  18  -394648
# 189   6  -333968
# 190   1  -282496
# 191  12  -268414
# 192   0  -258014
# 193  10  -246080
# ...

# %%
#Files cleaning Cell: Transform the file into csv compatible
# Learning with text + title sentiment on Sentiment dic (bad model)
with open('/home/lucas/Desktop/modeldata.txt') as ff:
    with open('/home/lucas/Desktop/cleaneddata.clean','w') as out2:
        for line in ff.readlines():
            out2.write(','.join(line.split()) + '\n')

# %%
#Extract data from csv file
raw = pd.read_csv('/home/lucas/Desktop/cleaneddata.clean')
X1 = raw.ix[:,1].values
X2 = raw.ix[:,2].values
Y = raw.ix[:,0].values
features = np.array([X1,X2]).T

print raw
print features
print Y
# Out:
#       0  -0.034578146611341634  -3
# 0     1              -0.018009   0
# 1     2               0.023418   0
# 2     3               0.021930   0
# 3     4               0.005668   0
# 4     5               0.035144   0
# 5     6               0.014957   4
# 6     7               0.045614   0
# 7     8              -0.033210  -8
# 8     9               0.001133   0
# 9    10              -0.000982   0
# 10   11              -0.081616  -2
# 11   12               0.000000   0
# 12   13              -0.014306   0
# 13   14              -0.017997  -2
# 14   15               0.042553   0
# 15   16              -0.008628  -2
# 16   17              -0.039779  -4
# 17   18               0.049797   0
# 18   19               0.000000   0
# 19    0               0.002222  -1
# 20    1              -0.010172   0
# 21    2              -0.018287   0
# 22    3              -0.010929   0
# 23    4              -0.034578  -3
# 24    5              -0.027544  -1
# 25    6               0.018834   0
# ...

# %%
# Creation qnd training of the model
rfr = RandomForestRegressor()
rfr.fit(features,Y)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=10, n_jobs=1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False)

# %%
#sentiment = -30587
sentiment = np.array([0.007047768206734534, -1])
print('random foret score',rfr.predict(sentiment))
# Out:
# ('random foret score', array([ 11.7]))
